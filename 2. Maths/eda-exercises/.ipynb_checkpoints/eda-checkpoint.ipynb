# %% [markdown]
# <h1><center>L&T LTFS Dataset</center></h1>

# %% [markdown]
# Question: How can we say our predictions will work for new data?

# %% [markdown]
# <h2>Data columns descriptions</h2>

# %% [markdown]
# disbursed_amoun -

# %% [markdown]
# <h2>Importing the required libraries</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# <h2>Reading and understanding the dataset file</h2>

# %%
df = pd.read_csv("./data/train.csv", index_col = 0)

# %%
df.shape    # other similar methods - df.ndims, df.size
# Out:
# (233154, 40)

# %%
df.head()    # df.sample for single randomly chosen row
# Out:
#           disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# UniqueID
# 420825               50578       58400  89.55         67        22807
# 537409               47145       65550  73.23         67        22807
# 417566               53278       61360  89.63         67        22807
# 624493               57513       66113  88.48         67        22807
# 539055               52378       60300  88.39         67        22807
#
#           manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  \
# UniqueID
# 420825                 45                1441      01-01-84        Salaried
# 537409                 45                1502      31-07-85   Self employed
# 417566                 45                1497      24-08-85   Self employed
# 624493                 45                1501      30-12-93   Self employed
# 539055                 45                1495      09-12-77   Self employed
#
#          DisbursalDate  ...  SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  \
# UniqueID                ...
# 420825        03-08-18  ...                      0                     0
# 537409        26-09-18  ...                      0                     0
# 417566        01-08-18  ...                      0                     0
# 624493        26-10-18  ...                      0                     0
# 539055        26-09-18  ...                      0                     0
#
#           PRIMARY.INSTAL.AMT  SEC.INSTAL.AMT  NEW.ACCTS.IN.LAST.SIX.MONTHS  \
# UniqueID
# 420825                     0               0                             0
# 537409                  1991               0                             0
# 417566                     0               0                             0
# 624493                    31               0                             0
# 539055                     0               0                             0
#
#           DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS  AVERAGE.ACCT.AGE  \
# UniqueID
# 420825                                      0         0yrs 0mon
# 537409                                      1        1yrs 11mon
# 417566                                      0         0yrs 0mon
# 624493                                      0         0yrs 8mon
# 539055                                      0         0yrs 0mon
#
#           CREDIT.HISTORY.LENGTH  NO.OF_INQUIRIES loan_default
# UniqueID
# 420825                0yrs 0mon                0            0
# 537409               1yrs 11mon                0            1
# 417566                0yrs 0mon                0            0
# 624493                1yrs 3mon                1            1
# 539055                0yrs 0mon                1            1
#
# [5 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233154 entries, 420825 to 630213
# Data columns (total 40 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   disbursed_amount                     233154 non-null  int64
#  1   asset_cost                           233154 non-null  int64
#  2   ltv                                  233154 non-null  float64
#  3   branch_id                            233154 non-null  int64
#  4   supplier_id                          233154 non-null  int64
#  5   manufacturer_id                      233154 non-null  int64
#  6   Current_pincode_ID                   233154 non-null  int64
#  7   Date.of.Birth                        233154 non-null  object
#  8   Employment.Type                      225493 non-null  object
#  9   DisbursalDate                        233154 non-null  object
#  10  State_ID                             233154 non-null  int64
#  11  Employee_code_ID                     233154 non-null  int64
#  12  MobileNo_Avl_Flag                    233154 non-null  int64
#  13  Aadhar_flag                          233154 non-null  int64
#  14  PAN_flag                             233154 non-null  int64
#  15  VoterID_flag                         233154 non-null  int64
#  16  Driving_flag                         233154 non-null  int64
#  17  Passport_flag                        233154 non-null  int64
#  18  PERFORM_CNS.SCORE                    233154 non-null  int64
#  19  PERFORM_CNS.SCORE.DESCRIPTION        233154 non-null  object
#  20  PRI.NO.OF.ACCTS                      233154 non-null  int64
#  21  PRI.ACTIVE.ACCTS                     233154 non-null  int64
#  22  PRI.OVERDUE.ACCTS                    233154 non-null  int64
#  23  PRI.CURRENT.BALANCE                  233154 non-null  int64
#  24  PRI.SANCTIONED.AMOUNT                233154 non-null  int64
#  25  PRI.DISBURSED.AMOUNT                 233154 non-null  int64
#  26  SEC.NO.OF.ACCTS                      233154 non-null  int64
#  27  SEC.ACTIVE.ACCTS                     233154 non-null  int64
#  28  SEC.OVERDUE.ACCTS                    233154 non-null  int64
#  29  SEC.CURRENT.BALANCE                  233154 non-null  int64
#  30  SEC.SANCTIONED.AMOUNT                233154 non-null  int64
#  31  SEC.DISBURSED.AMOUNT                 233154 non-null  int64
#  32  PRIMARY.INSTAL.AMT                   233154 non-null  int64
#  33  SEC.INSTAL.AMT                       233154 non-null  int64
#  34  NEW.ACCTS.IN.LAST.SIX.MONTHS         233154 non-null  int64
#  35  DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS  233154 non-null  int64
#  36  AVERAGE.ACCT.AGE                     233154 non-null  object
#  37  CREDIT.HISTORY.LENGTH                233154 non-null  object
#  38  NO.OF_INQUIRIES                      233154 non-null  int64
#  39  loan_default                         233154 non-null  int64
# dtypes: float64(1), int64(33), object(6)
# memory usage: 72.9+ MB

# %% [markdown]
# df.info() gets the null values and dtypes in one go.<br><br>
# No null values except for Employment type. We see in last line that there are 33 int columns, 1 float column (ltv - this is a ratio term)<br>
# Datetimes are read as object dtype = Python dtype string. We will want to convert these object types to other dtypes to use for plotting<br><br>
# We can also load the data with<a href="https://stackoverflow.com/questions/21269399/datetime-dtypes-in-pandas-read-csv"> parse dates</a> option. <mark>(To try later)</mark>

# %%
# For statistics of all non-object dtype data
df.describe()
# Out:
#        disbursed_amount    asset_cost            ltv      branch_id  \
# count     233154.000000  2.331540e+05  233154.000000  233154.000000
# mean       54356.993528  7.586507e+04      74.746530      72.936094
# std        12971.314171  1.894478e+04      11.456636      69.834995
# min        13320.000000  3.700000e+04      10.030000       1.000000
# 25%        47145.000000  6.571700e+04      68.880000      14.000000
# 50%        53803.000000  7.094600e+04      76.800000      61.000000
# 75%        60413.000000  7.920175e+04      83.670000     130.000000
# max       990572.000000  1.628992e+06      95.000000     261.000000
#
#          supplier_id  manufacturer_id  Current_pincode_ID       State_ID  \
# count  233154.000000    233154.000000       233154.000000  233154.000000
# mean    19638.635035        69.028054         3396.880247       7.262243
# std      3491.949566        22.141304         2238.147502       4.482230
# min     10524.000000        45.000000            1.000000       1.000000
# 25%     16535.000000        48.000000         1511.000000       4.000000
# 50%     20333.000000        86.000000         2970.000000       6.000000
# 75%     23000.000000        86.000000         5677.000000      10.000000
# max     24803.000000       156.000000         7345.000000      22.000000
#
#        Employee_code_ID  MobileNo_Avl_Flag  ...  SEC.OVERDUE.ACCTS  \
# count     233154.000000           233154.0  ...      233154.000000
# mean        1549.477148                1.0  ...           0.007244
# std          975.261278                0.0  ...           0.111079
# min            1.000000                1.0  ...           0.000000
# 25%          713.000000                1.0  ...           0.000000
# 50%         1451.000000                1.0  ...           0.000000
# 75%         2362.000000                1.0  ...           0.000000
# max         3795.000000                1.0  ...           8.000000
#
#        SEC.CURRENT.BALANCE  SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  \
# count         2.331540e+05           2.331540e+05          2.331540e+05
# mean          5.427793e+03           7.295923e+03          7.179998e+03
# std           1.702370e+05           1.831560e+05          1.825925e+05
# min          -5.746470e+05           0.000000e+00          0.000000e+00
# 25%           0.000000e+00           0.000000e+00          0.000000e+00
# 50%           0.000000e+00           0.000000e+00          0.000000e+00
# 75%           0.000000e+00           0.000000e+00          0.000000e+00
# max           3.603285e+07           3.000000e+07          3.000000e+07
#
#        PRIMARY.INSTAL.AMT  SEC.INSTAL.AMT  NEW.ACCTS.IN.LAST.SIX.MONTHS  \
# count        2.331540e+05    2.331540e+05                 233154.000000
# mean         1.310548e+04    3.232684e+02                      0.381833
# std          1.513679e+05    1.555369e+04                      0.955107
# min          0.000000e+00    0.000000e+00                      0.000000
# 25%          0.000000e+00    0.000000e+00                      0.000000
# 50%          0.000000e+00    0.000000e+00                      0.000000
# 75%          1.999000e+03    0.000000e+00                      0.000000
# max          2.564281e+07    4.170901e+06                     35.000000
#
#        DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS  NO.OF_INQUIRIES   loan_default
# count                        233154.000000    233154.000000  233154.000000
# mean                              0.097481         0.206615       0.217071
# std                               0.384439         0.706498       0.412252
# min                               0.000000         0.000000       0.000000
# 25%                               0.000000         0.000000       0.000000
# 50%                               0.000000         0.000000       0.000000
# 75%                               0.000000         0.000000       0.000000
# max                              20.000000        36.000000       1.000000
#
# [8 rows x 34 columns]

# %%
# This is superfluous, as df.info() does this and more
# df.dtypes

# %%
# Checking for null values in each column
df.isnull().sum()
# Out:
# disbursed_amount                          0
# asset_cost                                0
# ltv                                       0
# branch_id                                 0
# supplier_id                               0
# manufacturer_id                           0
# Current_pincode_ID                        0
# Date.of.Birth                             0
# Employment.Type                        7661
# DisbursalDate                             0
# State_ID                                  0
# Employee_code_ID                          0
# MobileNo_Avl_Flag                         0
# Aadhar_flag                               0
# PAN_flag                                  0
# VoterID_flag                              0
# Driving_flag                              0
# Passport_flag                             0
# PERFORM_CNS.SCORE                         0
# PERFORM_CNS.SCORE.DESCRIPTION             0
# PRI.NO.OF.ACCTS                           0
# PRI.ACTIVE.ACCTS                          0
# PRI.OVERDUE.ACCTS                         0
# PRI.CURRENT.BALANCE                       0
# PRI.SANCTIONED.AMOUNT                     0
# PRI.DISBURSED.AMOUNT                      0
# SEC.NO.OF.ACCTS                           0
# SEC.ACTIVE.ACCTS                          0
# SEC.OVERDUE.ACCTS                         0
# SEC.CURRENT.BALANCE                       0
# SEC.SANCTIONED.AMOUNT                     0
# SEC.DISBURSED.AMOUNT                      0
# PRIMARY.INSTAL.AMT                        0
# SEC.INSTAL.AMT                            0
# NEW.ACCTS.IN.LAST.SIX.MONTHS              0
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS       0
# AVERAGE.ACCT.AGE                          0
# CREDIT.HISTORY.LENGTH                     0
# NO.OF_INQUIRIES                           0
# loan_default                              0
# dtype: int64

# %% [markdown]
# Note the null values in Employment Type

# %% [markdown]
# <h2>Object type columns</h2>

# %%
df.loc[:, df.dtypes == object].head()
# Out:
#          Date.of.Birth Employment.Type DisbursalDate  \
# UniqueID
# 420825        01-01-84        Salaried      03-08-18
# 537409        31-07-85   Self employed      26-09-18
# 417566        24-08-85   Self employed      01-08-18
# 624493        30-12-93   Self employed      26-10-18
# 539055        09-12-77   Self employed      26-09-18
#
#          PERFORM_CNS.SCORE.DESCRIPTION AVERAGE.ACCT.AGE CREDIT.HISTORY.LENGTH
# UniqueID
# 420825     No Bureau History Available        0yrs 0mon             0yrs 0mon
# 537409                   I-Medium Risk       1yrs 11mon            1yrs 11mon
# 417566     No Bureau History Available        0yrs 0mon             0yrs 0mon
# 624493                L-Very High Risk        0yrs 8mon             1yrs 3mon
# 539055     No Bureau History Available        0yrs 0mon             0yrs 0mon

# %% [markdown]
# <h3>1. Employment Type</h3>

# %%
# Get rows where Employment Type has Nan value
empty_Employment = df[df['Employment.Type'].isnull()]['Employment.Type']
print(empty_Employment)
# Out:
# UniqueID
# 525234    NaN
# 637252    NaN
# 584433    NaN
# 515149    NaN
# 547112    NaN
#          ...
# 494458    NaN
# 419420    NaN
# 553774    NaN
# 594901    NaN
# 563437    NaN
# Name: Employment.Type, Length: 7661, dtype: object

# %%
# Find percentage of rows where Employment type is nan
Nan_percent = df['Employment.Type'].isnull().sum()*100/len(df)
Nan_percent
# Out:
# 3.2858110948128703

# %%
df['Employment.Type'].unique()
# Out:
# array(['Salaried', 'Self employed', nan], dtype=object)

# %% [markdown]
# If we want to play around with this column's data, we will need to change this to numerical values.<br><br>
# Like categories:<br>
# 1: 'Salary'<br>
# 2: 'Self employed'<br>
# 3: nan<br>
# Can use the replace method for this.

# %%
df['Employment.Type.Numeric'] = df['Employment.Type'].replace({'Salaried': 1, 'Self employed': 2, np.nan: 3})

# %%
df.head()
# Out:
#           disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# UniqueID
# 420825               50578       58400  89.55         67        22807
# 537409               47145       65550  73.23         67        22807
# 417566               53278       61360  89.63         67        22807
# 624493               57513       66113  88.48         67        22807
# 539055               52378       60300  88.39         67        22807
#
#           manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  \
# UniqueID
# 420825                 45                1441      01-01-84        Salaried
# 537409                 45                1502      31-07-85   Self employed
# 417566                 45                1497      24-08-85   Self employed
# 624493                 45                1501      30-12-93   Self employed
# 539055                 45                1495      09-12-77   Self employed
#
#          DisbursalDate  ...  SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# UniqueID                ...
# 420825        03-08-18  ...                     0                   0
# 537409        26-09-18  ...                     0                1991
# 417566        01-08-18  ...                     0                   0
# 624493        26-10-18  ...                     0                  31
# 539055        26-09-18  ...                     0                   0
#
#           SEC.INSTAL.AMT  NEW.ACCTS.IN.LAST.SIX.MONTHS  \
# UniqueID
# 420825                 0                             0
# 537409                 0                             0
# 417566                 0                             0
# 624493                 0                             0
# 539055                 0                             0
#
#           DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS  AVERAGE.ACCT.AGE  \
# UniqueID
# 420825                                      0         0yrs 0mon
# 537409                                      1        1yrs 11mon
# 417566                                      0         0yrs 0mon
# 624493                                      0         0yrs 8mon
# 539055                                      0         0yrs 0mon
#
#           CREDIT.HISTORY.LENGTH  NO.OF_INQUIRIES  loan_default  \
# UniqueID
# 420825                0yrs 0mon                0             0
# 537409               1yrs 11mon                0             1
# 417566                0yrs 0mon                0             0
# 624493                1yrs 3mon                1             1
# 539055                0yrs 0mon                1             1
#
#          Employment.Type.Numeric
# UniqueID
# 420825                         1
# 537409                         2
# 417566                         2
# 624493                         2
# 539055                         2
#
# [5 rows x 41 columns]

# %%
# Employment numeric type has no null values as they are replaced by 3.
# Can manipulate accordingly later
df.isnull().sum()
# Out:
# disbursed_amount                          0
# asset_cost                                0
# ltv                                       0
# branch_id                                 0
# supplier_id                               0
# manufacturer_id                           0
# Current_pincode_ID                        0
# Date.of.Birth                             0
# Employment.Type                        7661
# DisbursalDate                             0
# State_ID                                  0
# Employee_code_ID                          0
# MobileNo_Avl_Flag                         0
# Aadhar_flag                               0
# PAN_flag                                  0
# VoterID_flag                              0
# Driving_flag                              0
# Passport_flag                             0
# PERFORM_CNS.SCORE                         0
# PERFORM_CNS.SCORE.DESCRIPTION             0
# PRI.NO.OF.ACCTS                           0
# PRI.ACTIVE.ACCTS                          0
# PRI.OVERDUE.ACCTS                         0
# PRI.CURRENT.BALANCE                       0
# PRI.SANCTIONED.AMOUNT                     0
# PRI.DISBURSED.AMOUNT                      0
# SEC.NO.OF.ACCTS                           0
# SEC.ACTIVE.ACCTS                          0
# SEC.OVERDUE.ACCTS                         0
# SEC.CURRENT.BALANCE                       0
# SEC.SANCTIONED.AMOUNT                     0
# SEC.DISBURSED.AMOUNT                      0
# PRIMARY.INSTAL.AMT                        0
# SEC.INSTAL.AMT                            0
# NEW.ACCTS.IN.LAST.SIX.MONTHS              0
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS       0
# AVERAGE.ACCT.AGE                          0
# CREDIT.HISTORY.LENGTH                     0
# NO.OF_INQUIRIES                           0
# loan_default                              0
# Employment.Type.Numeric                   0
# dtype: int64

# %% [markdown]
# <h3>2: Date of Birth, 3: Disbursal Date</h3>

# %% [markdown]
# <ol>
#     <li>https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html</li>
#     <li>https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html ---> date_parser </li>
# </ol>

# %%
df['Date.of.Birth.datetime'] = pd.to_datetime(df['Date.of.Birth'], format = '%d-%m-%y')

# %%
df['DisbursalDate.datetime'] = df['DisbursalDate'].apply(lambda x: datetime.strptime(x, '%d-%m-%y'))

# %%
df.head()
# Out:
#           disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# UniqueID
# 420825               50578       58400  89.55         67        22807
# 537409               47145       65550  73.23         67        22807
# 417566               53278       61360  89.63         67        22807
# 624493               57513       66113  88.48         67        22807
# 539055               52378       60300  88.39         67        22807
#
#           manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  \
# UniqueID
# 420825                 45                1441      01-01-84        Salaried
# 537409                 45                1502      31-07-85   Self employed
# 417566                 45                1497      24-08-85   Self employed
# 624493                 45                1501      30-12-93   Self employed
# 539055                 45                1495      09-12-77   Self employed
#
#          DisbursalDate  ...  SEC.INSTAL.AMT  NEW.ACCTS.IN.LAST.SIX.MONTHS  \
# UniqueID                ...
# 420825        03-08-18  ...               0                             0
# 537409        26-09-18  ...               0                             0
# 417566        01-08-18  ...               0                             0
# 624493        26-10-18  ...               0                             0
# 539055        26-09-18  ...               0                             0
#
#           DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS  AVERAGE.ACCT.AGE  \
# UniqueID
# 420825                                      0         0yrs 0mon
# 537409                                      1        1yrs 11mon
# 417566                                      0         0yrs 0mon
# 624493                                      0         0yrs 8mon
# 539055                                      0         0yrs 0mon
#
#           CREDIT.HISTORY.LENGTH  NO.OF_INQUIRIES  loan_default  \
# UniqueID
# 420825                0yrs 0mon                0             0
# 537409               1yrs 11mon                0             1
# 417566                0yrs 0mon                0             0
# 624493                1yrs 3mon                1             1
# 539055                0yrs 0mon                1             1
#
#           Employment.Type.Numeric  Date.of.Birth.datetime  \
# UniqueID
# 420825                          1              1984-01-01
# 537409                          2              1985-07-31
# 417566                          2              1985-08-24
# 624493                          2              1993-12-30
# 539055                          2              1977-12-09
#
#          DisbursalDate.datetime
# UniqueID
# 420825               2018-08-03
# 537409               2018-09-26
# 417566               2018-08-01
# 624493               2018-10-26
# 539055               2018-09-26
#
# [5 rows x 43 columns]

# %%
# Check null values to make sure all dates were parsed and formatted
df.isnull().sum()
# Out:
# disbursed_amount                          0
# asset_cost                                0
# ltv                                       0
# branch_id                                 0
# supplier_id                               0
# manufacturer_id                           0
# Current_pincode_ID                        0
# Date.of.Birth                             0
# Employment.Type                        7661
# DisbursalDate                             0
# State_ID                                  0
# Employee_code_ID                          0
# MobileNo_Avl_Flag                         0
# Aadhar_flag                               0
# PAN_flag                                  0
# VoterID_flag                              0
# Driving_flag                              0
# Passport_flag                             0
# PERFORM_CNS.SCORE                         0
# PERFORM_CNS.SCORE.DESCRIPTION             0
# PRI.NO.OF.ACCTS                           0
# PRI.ACTIVE.ACCTS                          0
# PRI.OVERDUE.ACCTS                         0
# PRI.CURRENT.BALANCE                       0
# PRI.SANCTIONED.AMOUNT                     0
# PRI.DISBURSED.AMOUNT                      0
# SEC.NO.OF.ACCTS                           0
# SEC.ACTIVE.ACCTS                          0
# SEC.OVERDUE.ACCTS                         0
# SEC.CURRENT.BALANCE                       0
# SEC.SANCTIONED.AMOUNT                     0
# SEC.DISBURSED.AMOUNT                      0
# PRIMARY.INSTAL.AMT                        0
# SEC.INSTAL.AMT                            0
# NEW.ACCTS.IN.LAST.SIX.MONTHS              0
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS       0
# AVERAGE.ACCT.AGE                          0
# CREDIT.HISTORY.LENGTH                     0
# NO.OF_INQUIRIES                           0
# loan_default                              0
# Employment.Type.Numeric                   0
# Date.of.Birth.datetime                    0
# DisbursalDate.datetime                    0
# dtype: int64

# %%
# https://stackoverflow.com/questions/29206612/difference-between-data-type-datetime64ns-and-m8ns
df['Date.of.Birth.datetime'].dtype
# np.dtype('datetime64[ns]') == np.dtype('<M8[ns]')
# Out:
# dtype('<M8[ns]')

# %%
# Extracting only the rows where date time parsing gives year > 2021
df[df['Date.of.Birth.datetime'].dt.year > 2021]['Date.of.Birth']
# Out:
# UniqueID
# 510980    01-06-68
# 440293    02-08-68
# 501823    01-06-66
# 460555    01-06-64
# 517611    01-01-67
#             ...
# 608319    13-08-63
# 602689    15-11-63
# 450782    16-01-64
# 626823    25-01-67
# 613161    15-06-63
# Name: Date.of.Birth, Length: 19866, dtype: object

# %%
df[df['DisbursalDate.datetime'].dt.year > 2021]['DisbursalDate']
# Out:
# Series([], Name: DisbursalDate, dtype: object)

# %% [markdown]
# <h4>Explanation for above behavior</h4><br>
# <a href = 'https://stackoverflow.com/questions/37766353/pandas-to-datetime-parsing-wrong-year'>Cutoff year</a> in python datetime library
# <p>Below '31-Dec-68' --> 2068 <br>
#    Above '1-Jan-69' --> 1968
# </p>

# %% [markdown]
# <h3>4: PERFORM_CNS.SCORE.DESCRIPTION</h3>

# %%
# 20 unique values
df['PERFORM_CNS.SCORE.DESCRIPTION'].unique()
# Out:
# array(['No Bureau History Available', 'I-Medium Risk', 'L-Very High Risk',
#        'A-Very Low Risk',
#        'Not Scored: Not Enough Info available on the customer',
#        'D-Very Low Risk', 'M-Very High Risk', 'B-Very Low Risk',
#        'C-Very Low Risk', 'E-Low Risk', 'H-Medium Risk', 'F-Low Risk',
#        'K-High Risk',
#        'Not Scored: No Activity seen on the customer (Inactive)',
#        'Not Scored: Sufficient History Not Available',
#        'Not Scored: No Updates available in last 36 months', 'G-Low Risk',
#        'J-High Risk', 'Not Scored: Only a Guarantor',
#        'Not Scored: More than 50 active Accounts found'], dtype=object)

# %% [markdown]
# <h3>5: AVERAGE.ACCT.AGE, 6: CREDIT.HISTORY.LENGTH</h3>

# %%
df['AVERAGE.ACCT.AGE'].head()
# Out:
# UniqueID
# 420825     0yrs 0mon
# 537409    1yrs 11mon
# 417566     0yrs 0mon
# 624493     0yrs 8mon
# 539055     0yrs 0mon
# Name: AVERAGE.ACCT.AGE, dtype: object

# %%
df['AVERAGE.ACCT.AGE'].str.split()
# Out:
# UniqueID
# 420825     [0yrs, 0mon]
# 537409    [1yrs, 11mon]
# 417566     [0yrs, 0mon]
# 624493     [0yrs, 8mon]
# 539055     [0yrs, 0mon]
#               ...
# 626432     [1yrs, 9mon]
# 606141     [0yrs, 6mon]
# 613658     [0yrs, 0mon]
# 548084     [0yrs, 0mon]
# 630213     [0yrs, 0mon]
# Name: AVERAGE.ACCT.AGE, Length: 233154, dtype: object

# %%
df['AVERAGE.ACCT.AGE.months'] =  df['AVERAGE.ACCT.AGE'].str.split().apply(lambda row: int(row[0].strip('yrs'))*12
                                                                                    + int(row[1].strip('mon')))

# %%
df[['AVERAGE.ACCT.AGE','AVERAGE.ACCT.AGE.months']].head()
# Out:
#          AVERAGE.ACCT.AGE  AVERAGE.ACCT.AGE.months
# UniqueID
# 420825          0yrs 0mon                        0
# 537409         1yrs 11mon                       23
# 417566          0yrs 0mon                        0
# 624493          0yrs 8mon                        8
# 539055          0yrs 0mon                        0

# %% [markdown]
# <h2>Finding the relationships</h2>

# %%
# For any non-numeric data type columns in the dataframe, it is ignored. 
df.corr()
# Out:
#                                      disbursed_amount  asset_cost       ltv  \
# disbursed_amount                             1.000000    0.752668  0.376747
# asset_cost                                   0.752668    1.000000 -0.301188
# ltv                                          0.376747   -0.301188  1.000000
# branch_id                                    0.018328    0.018586  0.006382
# supplier_id                                  0.078596    0.150002 -0.103732
# manufacturer_id                              0.095203   -0.005256  0.121003
# Current_pincode_ID                           0.068540    0.275878 -0.300112
# State_ID                                    -0.023956   -0.026348  0.004882
# Employee_code_ID                             0.010120    0.008711  0.004940
# MobileNo_Avl_Flag                                 NaN         NaN       NaN
# Aadhar_flag                                 -0.015589   -0.093716  0.106953
# PAN_flag                                     0.014490    0.048075 -0.037786
# VoterID_flag                                 0.011665    0.083899 -0.098393
# Driving_flag                                 0.001381    0.020484 -0.024060
# Passport_flag                                0.008291    0.005542  0.004467
# PERFORM_CNS.SCORE                            0.011409   -0.047398  0.084993
# PRI.NO.OF.ACCTS                              0.034461   -0.026798  0.086571
# PRI.ACTIVE.ACCTS                             0.039542   -0.021692  0.087929
# PRI.OVERDUE.ACCTS                            0.019422   -0.014782  0.051770
# PRI.CURRENT.BALANCE                          0.015713   -0.004356  0.026714
# PRI.SANCTIONED.AMOUNT                        0.006294   -0.001180  0.009955
# PRI.DISBURSED.AMOUNT                         0.006412   -0.001221  0.010177
# SEC.NO.OF.ACCTS                             -0.014916   -0.022600  0.013019
# SEC.ACTIVE.ACCTS                            -0.014275   -0.020359  0.010565
# SEC.OVERDUE.ACCTS                           -0.007305   -0.013455  0.010256
# SEC.CURRENT.BALANCE                         -0.004227   -0.008697  0.007195
# SEC.SANCTIONED.AMOUNT                       -0.005271   -0.010776  0.008800
# SEC.DISBURSED.AMOUNT                        -0.005119   -0.010594  0.008733
# PRIMARY.INSTAL.AMT                           0.002350   -0.004356  0.007358
# SEC.INSTAL.AMT                              -0.005525   -0.005738  0.000481
# NEW.ACCTS.IN.LAST.SIX.MONTHS                 0.035880   -0.021968  0.083824
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS          0.020198   -0.007932  0.041921
# NO.OF_INQUIRIES                              0.038513   -0.017301  0.085725
# loan_default                                 0.077675    0.014261  0.098208
# Employment.Type.Numeric                      0.005300    0.080863 -0.106681
# AVERAGE.ACCT.AGE.months                      0.004205   -0.015614  0.029853
#
#                                      branch_id  supplier_id  manufacturer_id  \
# disbursed_amount                      0.018328     0.078596         0.095203
# asset_cost                            0.018586     0.150002        -0.005256
# ltv                                   0.006382    -0.103732         0.121003
# branch_id                             1.000000     0.225744        -0.049957
# supplier_id                           0.225744     1.000000        -0.063916
# manufacturer_id                      -0.049957    -0.063916         1.000000
# Current_pincode_ID                    0.048192     0.187401        -0.104349
# State_ID                              0.187782     0.105502         0.026412
# Employee_code_ID                      0.088764     0.095792        -0.045009
# MobileNo_Avl_Flag                          NaN          NaN              NaN
# Aadhar_flag                          -0.036384    -0.081161         0.041251
# PAN_flag                              0.030206     0.036804        -0.029272
# VoterID_flag                          0.021387     0.079355        -0.046489
# Driving_flag                         -0.015503    -0.015682         0.004777
# Passport_flag                        -0.008537    -0.008773         0.016338
# PERFORM_CNS.SCORE                    -0.018049    -0.077029         0.073012
# PRI.NO.OF.ACCTS                      -0.010384    -0.070536         0.068371
# PRI.ACTIVE.ACCTS                     -0.006403    -0.066930         0.065589
# PRI.OVERDUE.ACCTS                    -0.005546    -0.042692         0.025992
# PRI.CURRENT.BALANCE                  -0.004133    -0.022582         0.031722
# PRI.SANCTIONED.AMOUNT                -0.003370    -0.012959         0.017242
# PRI.DISBURSED.AMOUNT                 -0.003412    -0.012950         0.017080
# SEC.NO.OF.ACCTS                      -0.003194    -0.025809         0.008392
# SEC.ACTIVE.ACCTS                     -0.001957    -0.019885         0.005898
# SEC.OVERDUE.ACCTS                    -0.007104    -0.015665         0.008152
# SEC.CURRENT.BALANCE                   0.001418    -0.008729         0.003106
# SEC.SANCTIONED.AMOUNT                 0.002404    -0.010175         0.003206
# SEC.DISBURSED.AMOUNT                  0.002457    -0.010031         0.003301
# PRIMARY.INSTAL.AMT                    0.004955    -0.011953         0.014116
# SEC.INSTAL.AMT                        0.004265    -0.005826         0.003020
# NEW.ACCTS.IN.LAST.SIX.MONTHS         -0.008354    -0.053264         0.050079
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS  -0.001730    -0.024622         0.019438
# NO.OF_INQUIRIES                      -0.001813    -0.030988         0.010012
# loan_default                          0.030193     0.027357        -0.025039
# Employment.Type.Numeric              -0.021243     0.072066        -0.037311
# AVERAGE.ACCT.AGE.months               0.005338    -0.034095         0.042522
#
#                                      Current_pincode_ID  State_ID  \
# disbursed_amount                               0.068540 -0.023956
# asset_cost                                     0.275878 -0.026348
# ltv                                           -0.300112  0.004882
# branch_id                                      0.048192  0.187782
# supplier_id                                    0.187401  0.105502
# manufacturer_id                               -0.104349  0.026412
# Current_pincode_ID                             1.000000  0.047903
# State_ID                                       0.047903  1.000000
# Employee_code_ID                              -0.042609  0.117309
# MobileNo_Avl_Flag                                   NaN       NaN
# Aadhar_flag                                   -0.309285 -0.169882
# PAN_flag                                       0.041118  0.113939
# VoterID_flag                                   0.281934  0.151839
# Driving_flag                                   0.039667  0.027886
# Passport_flag                                 -0.008913 -0.000915
# PERFORM_CNS.SCORE                             -0.161664 -0.042323
# PRI.NO.OF.ACCTS                               -0.084687 -0.008704
# PRI.ACTIVE.ACCTS                              -0.117882 -0.021061
# PRI.OVERDUE.ACCTS                             -0.062177 -0.012381
# PRI.CURRENT.BALANCE                           -0.055948 -0.006359
# PRI.SANCTIONED.AMOUNT                         -0.025843 -0.004304
# PRI.DISBURSED.AMOUNT                          -0.025697 -0.004129
# SEC.NO.OF.ACCTS                               -0.051766  0.031245
# SEC.ACTIVE.ACCTS                              -0.049852  0.032142
# SEC.OVERDUE.ACCTS                             -0.036228  0.015679
# SEC.CURRENT.BALANCE                           -0.021048  0.013231
# SEC.SANCTIONED.AMOUNT                         -0.026059  0.017842
# SEC.DISBURSED.AMOUNT                          -0.025630  0.017651
# PRIMARY.INSTAL.AMT                             0.002275  0.015843
# SEC.INSTAL.AMT                                -0.006305  0.009850
# NEW.ACCTS.IN.LAST.SIX.MONTHS                  -0.100080 -0.014942
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS           -0.057419 -0.000655
# NO.OF_INQUIRIES                               -0.058821 -0.016129
# loan_default                                   0.028419  0.048075
# Employment.Type.Numeric                        0.203651 -0.031541
# AVERAGE.ACCT.AGE.months                       -0.062704 -0.008205
#
#                                      Employee_code_ID  MobileNo_Avl_Flag  ...  \
# disbursed_amount                             0.010120                NaN  ...
# asset_cost                                   0.008711                NaN  ...
# ltv                                          0.004940                NaN  ...
# branch_id                                    0.088764                NaN  ...
# supplier_id                                  0.095792                NaN  ...
# manufacturer_id                             -0.045009                NaN  ...
# Current_pincode_ID                          -0.042609                NaN  ...
# State_ID                                     0.117309                NaN  ...
# Employee_code_ID                             1.000000                NaN  ...
# MobileNo_Avl_Flag                                 NaN                NaN  ...
# Aadhar_flag                                  0.048759                NaN  ...
# PAN_flag                                    -0.027579                NaN  ...
# VoterID_flag                                -0.047342                NaN  ...
# Driving_flag                                -0.017617                NaN  ...
# Passport_flag                               -0.007205                NaN  ...
# PERFORM_CNS.SCORE                           -0.005767                NaN  ...
# PRI.NO.OF.ACCTS                              0.009197                NaN  ...
# PRI.ACTIVE.ACCTS                             0.006111                NaN  ...
# PRI.OVERDUE.ACCTS                           -0.000116                NaN  ...
# PRI.CURRENT.BALANCE                          0.003528                NaN  ...
# PRI.SANCTIONED.AMOUNT                       -0.001105                NaN  ...
# PRI.DISBURSED.AMOUNT                        -0.001088                NaN  ...
# SEC.NO.OF.ACCTS                             -0.001385                NaN  ...
# SEC.ACTIVE.ACCTS                            -0.003331                NaN  ...
# SEC.OVERDUE.ACCTS                           -0.006537                NaN  ...
# SEC.CURRENT.BALANCE                         -0.003543                NaN  ...
# SEC.SANCTIONED.AMOUNT                       -0.002259                NaN  ...
# SEC.DISBURSED.AMOUNT                        -0.002224                NaN  ...
# PRIMARY.INSTAL.AMT                           0.013470                NaN  ...
# SEC.INSTAL.AMT                               0.001894                NaN  ...
# NEW.ACCTS.IN.LAST.SIX.MONTHS                 0.005473                NaN  ...
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS          0.003624                NaN  ...
# NO.OF_INQUIRIES                             -0.002108                NaN  ...
# loan_default                                 0.020657                NaN  ...
# Employment.Type.Numeric                      0.031426                NaN  ...
# AVERAGE.ACCT.AGE.months                      0.000297                NaN  ...
#
#                                      SEC.SANCTIONED.AMOUNT  \
# disbursed_amount                                 -0.005271
# asset_cost                                       -0.010776
# ltv                                               0.008800
# branch_id                                         0.002404
# supplier_id                                      -0.010175
# manufacturer_id                                   0.003206
# Current_pincode_ID                               -0.026059
# State_ID                                          0.017842
# Employee_code_ID                                 -0.002259
# MobileNo_Avl_Flag                                      NaN
# Aadhar_flag                                       0.007591
# PAN_flag                                          0.015279
# VoterID_flag                                     -0.006619
# Driving_flag                                      0.002600
# Passport_flag                                     0.003539
# PERFORM_CNS.SCORE                                 0.024365
# PRI.NO.OF.ACCTS                                   0.024877
# PRI.ACTIVE.ACCTS                                  0.026805
# PRI.OVERDUE.ACCTS                                 0.017194
# PRI.CURRENT.BALANCE                               0.021179
# PRI.SANCTIONED.AMOUNT                             0.011859
# PRI.DISBURSED.AMOUNT                              0.011771
# SEC.NO.OF.ACCTS                                   0.359193
# SEC.ACTIVE.ACCTS                                  0.452693
# SEC.OVERDUE.ACCTS                                 0.234422
# SEC.CURRENT.BALANCE                               0.929196
# SEC.SANCTIONED.AMOUNT                             1.000000
# SEC.DISBURSED.AMOUNT                              0.999646
# PRIMARY.INSTAL.AMT                                0.011448
# SEC.INSTAL.AMT                                    0.113395
# NEW.ACCTS.IN.LAST.SIX.MONTHS                      0.055801
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS               0.055198
# NO.OF_INQUIRIES                                   0.002675
# loan_default                                     -0.006354
# Employment.Type.Numeric                          -0.004312
# AVERAGE.ACCT.AGE.months                           0.037574
#
#                                      SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# disbursed_amount                                -0.005119            0.002350
# asset_cost                                      -0.010594           -0.004356
# ltv                                              0.008733            0.007358
# branch_id                                        0.002457            0.004955
# supplier_id                                     -0.010031           -0.011953
# manufacturer_id                                  0.003301            0.014116
# Current_pincode_ID                              -0.025630            0.002275
# State_ID                                         0.017651            0.015843
# Employee_code_ID                                -0.002224            0.013470
# MobileNo_Avl_Flag                                     NaN                 NaN
# Aadhar_flag                                      0.007540            0.014832
# PAN_flag                                         0.014907           -0.010851
# VoterID_flag                                    -0.006580           -0.018820
# Driving_flag                                     0.002583            0.006219
# Passport_flag                                    0.003506            0.012914
# PERFORM_CNS.SCORE                                0.023953            0.071309
# PRI.NO.OF.ACCTS                                  0.024551            0.269546
# PRI.ACTIVE.ACCTS                                 0.026325            0.192397
# PRI.OVERDUE.ACCTS                                0.016855            0.103095
# PRI.CURRENT.BALANCE                              0.021152            0.152499
# PRI.SANCTIONED.AMOUNT                            0.011843            0.072591
# PRI.DISBURSED.AMOUNT                             0.011757            0.073058
# SEC.NO.OF.ACCTS                                  0.353330            0.009986
# SEC.ACTIVE.ACCTS                                 0.445950            0.007063
# SEC.OVERDUE.ACCTS                                0.230982            0.002066
# SEC.CURRENT.BALANCE                              0.929995            0.010393
# SEC.SANCTIONED.AMOUNT                            0.999646            0.011448
# SEC.DISBURSED.AMOUNT                             1.000000            0.011469
# PRIMARY.INSTAL.AMT                               0.011469            1.000000
# SEC.INSTAL.AMT                                   0.112880            0.010849
# NEW.ACCTS.IN.LAST.SIX.MONTHS                     0.054886            0.127796
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS              0.054374            0.090364
# NO.OF_INQUIRIES                                  0.002581            0.008967
# loan_default                                    -0.006248           -0.010616
# Employment.Type.Numeric                         -0.004315            0.013409
# AVERAGE.ACCT.AGE.months                          0.037020            0.039689
#
#                                      SEC.INSTAL.AMT  \
# disbursed_amount                          -0.005525
# asset_cost                                -0.005738
# ltv                                        0.000481
# branch_id                                  0.004265
# supplier_id                               -0.005826
# manufacturer_id                            0.003020
# Current_pincode_ID                        -0.006305
# State_ID                                   0.009850
# Employee_code_ID                           0.001894
# MobileNo_Avl_Flag                               NaN
# Aadhar_flag                                0.006273
# PAN_flag                                  -0.000219
# VoterID_flag                              -0.006019
# Driving_flag                              -0.000843
# Passport_flag                              0.000524
# PERFORM_CNS.SCORE                          0.015655
# PRI.NO.OF.ACCTS                            0.023421
# PRI.ACTIVE.ACCTS                           0.021210
# PRI.OVERDUE.ACCTS                          0.009324
# PRI.CURRENT.BALANCE                        0.006799
# PRI.SANCTIONED.AMOUNT                      0.003883
# PRI.DISBURSED.AMOUNT                       0.003806
# SEC.NO.OF.ACCTS                            0.235277
# SEC.ACTIVE.ACCTS                           0.148895
# SEC.OVERDUE.ACCTS                          0.077731
# SEC.CURRENT.BALANCE                        0.096351
# SEC.SANCTIONED.AMOUNT                      0.113395
# SEC.DISBURSED.AMOUNT                       0.112880
# PRIMARY.INSTAL.AMT                         0.010849
# SEC.INSTAL.AMT                             1.000000
# NEW.ACCTS.IN.LAST.SIX.MONTHS               0.028160
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS        0.018613
# NO.OF_INQUIRIES                            0.002736
# loan_default                              -0.001548
# Employment.Type.Numeric                   -0.005144
# AVERAGE.ACCT.AGE.months                    0.012456
#
#                                      NEW.ACCTS.IN.LAST.SIX.MONTHS  \
# disbursed_amount                                         0.035880
# asset_cost                                              -0.021968
# ltv                                                      0.083824
# branch_id                                               -0.008354
# supplier_id                                             -0.053264
# manufacturer_id                                          0.050079
# Current_pincode_ID                                      -0.100080
# State_ID                                                -0.014942
# Employee_code_ID                                         0.005473
# MobileNo_Avl_Flag                                             NaN
# Aadhar_flag                                              0.059269
# PAN_flag                                                 0.007046
# VoterID_flag                                            -0.059591
# Driving_flag                                            -0.000929
# Passport_flag                                            0.008052
# PERFORM_CNS.SCORE                                        0.346025
# PRI.NO.OF.ACCTS                                          0.537622
# PRI.ACTIVE.ACCTS                                         0.702943
# PRI.OVERDUE.ACCTS                                        0.109896
# PRI.CURRENT.BALANCE                                      0.198566
# PRI.SANCTIONED.AMOUNT                                    0.095074
# PRI.DISBURSED.AMOUNT                                     0.094681
# SEC.NO.OF.ACCTS                                          0.119791
# SEC.ACTIVE.ACCTS                                         0.134577
# SEC.OVERDUE.ACCTS                                        0.057046
# SEC.CURRENT.BALANCE                                      0.046465
# SEC.SANCTIONED.AMOUNT                                    0.055801
# SEC.DISBURSED.AMOUNT                                     0.054886
# PRIMARY.INSTAL.AMT                                       0.127796
# SEC.INSTAL.AMT                                           0.028160
# NEW.ACCTS.IN.LAST.SIX.MONTHS                             1.000000
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS                      0.182769
# NO.OF_INQUIRIES                                          0.264709
# loan_default                                            -0.029400
# Employment.Type.Numeric                                 -0.020828
# AVERAGE.ACCT.AGE.months                                  0.033372
#
#                                      DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS  \
# disbursed_amount                                                0.020198
# asset_cost                                                     -0.007932
# ltv                                                             0.041921
# branch_id                                                      -0.001730
# supplier_id                                                    -0.024622
# manufacturer_id                                                 0.019438
# Current_pincode_ID                                             -0.057419
# State_ID                                                       -0.000655
# Employee_code_ID                                                0.003624
# MobileNo_Avl_Flag                                                    NaN
# Aadhar_flag                                                     0.023823
# PAN_flag                                                       -0.002562
# VoterID_flag                                                   -0.027453
# Driving_flag                                                    0.011311
# Passport_flag                                                   0.006695
# PERFORM_CNS.SCORE                                               0.164745
# PRI.NO.OF.ACCTS                                                 0.314148
# PRI.ACTIVE.ACCTS                                                0.382584
# PRI.OVERDUE.ACCTS                                               0.471564
# PRI.CURRENT.BALANCE                                             0.244243
# PRI.SANCTIONED.AMOUNT                                           0.122028
# PRI.DISBURSED.AMOUNT                                            0.122650
# SEC.NO.OF.ACCTS                                                 0.100321
# SEC.ACTIVE.ACCTS                                                0.109194
# SEC.OVERDUE.ACCTS                                               0.108810
# SEC.CURRENT.BALANCE                                             0.044987
# SEC.SANCTIONED.AMOUNT                                           0.055198
# SEC.DISBURSED.AMOUNT                                            0.054374
# PRIMARY.INSTAL.AMT                                              0.090364
# SEC.INSTAL.AMT                                                  0.018613
# NEW.ACCTS.IN.LAST.SIX.MONTHS                                    0.182769
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS                             1.000000
# NO.OF_INQUIRIES                                                 0.070715
# loan_default                                                    0.034462
# Employment.Type.Numeric                                        -0.001633
# AVERAGE.ACCT.AGE.months                                         0.171348
#
#                                      NO.OF_INQUIRIES  loan_default  \
# disbursed_amount                            0.038513      0.077675
# asset_cost                                 -0.017301      0.014261
# ltv                                         0.085725      0.098208
# branch_id                                  -0.001813      0.030193
# supplier_id                                -0.030988      0.027357
# manufacturer_id                             0.010012     -0.025039
# Current_pincode_ID                         -0.058821      0.028419
# State_ID                                   -0.016129      0.048075
# Employee_code_ID                           -0.002108      0.020657
# MobileNo_Avl_Flag                                NaN           NaN
# Aadhar_flag                                 0.027317     -0.041593
# PAN_flag                                    0.016657      0.002046
# VoterID_flag                               -0.018285      0.043747
# Driving_flag                               -0.021179     -0.005821
# Passport_flag                              -0.001908     -0.007602
# PERFORM_CNS.SCORE                           0.152838     -0.057929
# PRI.NO.OF.ACCTS                             0.180744     -0.035456
# PRI.ACTIVE.ACCTS                            0.195484     -0.041451
# PRI.OVERDUE.ACCTS                           0.063780      0.040872
# PRI.CURRENT.BALANCE                         0.023861     -0.027386
# PRI.SANCTIONED.AMOUNT                       0.010743     -0.011304
# PRI.DISBURSED.AMOUNT                        0.010935     -0.011155
# SEC.NO.OF.ACCTS                             0.005035     -0.008385
# SEC.ACTIVE.ACCTS                            0.004830     -0.005993
# SEC.OVERDUE.ACCTS                           0.004975     -0.001371
# SEC.CURRENT.BALANCE                         0.002715     -0.005531
# SEC.SANCTIONED.AMOUNT                       0.002675     -0.006354
# SEC.DISBURSED.AMOUNT                        0.002581     -0.006248
# PRIMARY.INSTAL.AMT                          0.008967     -0.010616
# SEC.INSTAL.AMT                              0.002736     -0.001548
# NEW.ACCTS.IN.LAST.SIX.MONTHS                0.264709     -0.029400
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS         0.070715      0.034462
# NO.OF_INQUIRIES                             1.000000      0.043678
# loan_default                                0.043678      1.000000
# Employment.Type.Numeric                    -0.006353      0.024823
# AVERAGE.ACCT.AGE.months                     0.024883     -0.024781
#
#                                      Employment.Type.Numeric  \
# disbursed_amount                                    0.005300
# asset_cost                                          0.080863
# ltv                                                -0.106681
# branch_id                                          -0.021243
# supplier_id                                         0.072066
# manufacturer_id                                    -0.037311
# Current_pincode_ID                                  0.203651
# State_ID                                           -0.031541
# Employee_code_ID                                    0.031426
# MobileNo_Avl_Flag                                        NaN
# Aadhar_flag                                        -0.058794
# PAN_flag                                           -0.014600
# VoterID_flag                                        0.062433
# Driving_flag                                       -0.005205
# Passport_flag                                      -0.005094
# PERFORM_CNS.SCORE                                  -0.065804
# PRI.NO.OF.ACCTS                                    -0.004993
# PRI.ACTIVE.ACCTS                                   -0.025422
# PRI.OVERDUE.ACCTS                                   0.009134
# PRI.CURRENT.BALANCE                                 0.011260
# PRI.SANCTIONED.AMOUNT                               0.007052
# PRI.DISBURSED.AMOUNT                                0.007305
# SEC.NO.OF.ACCTS                                    -0.007784
# SEC.ACTIVE.ACCTS                                   -0.008243
# SEC.OVERDUE.ACCTS                                  -0.002778
# SEC.CURRENT.BALANCE                                -0.003346
# SEC.SANCTIONED.AMOUNT                              -0.004312
# SEC.DISBURSED.AMOUNT                               -0.004315
# PRIMARY.INSTAL.AMT                                  0.013409
# SEC.INSTAL.AMT                                     -0.005144
# NEW.ACCTS.IN.LAST.SIX.MONTHS                       -0.020828
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS                -0.001633
# NO.OF_INQUIRIES                                    -0.006353
# loan_default                                        0.024823
# Employment.Type.Numeric                             1.000000
# AVERAGE.ACCT.AGE.months                            -0.018974
#
#                                      AVERAGE.ACCT.AGE.months
# disbursed_amount                                    0.004205
# asset_cost                                         -0.015614
# ltv                                                 0.029853
# branch_id                                           0.005338
# supplier_id                                        -0.034095
# manufacturer_id                                     0.042522
# Current_pincode_ID                                 -0.062704
# State_ID                                           -0.008205
# Employee_code_ID                                    0.000297
# MobileNo_Avl_Flag                                        NaN
# Aadhar_flag                                         0.012217
# PAN_flag                                            0.015093
# VoterID_flag                                       -0.019884
# Driving_flag                                        0.017688
# Passport_flag                                       0.015182
# PERFORM_CNS.SCORE                                   0.474734
# PRI.NO.OF.ACCTS                                     0.234612
# PRI.ACTIVE.ACCTS                                    0.295723
# PRI.OVERDUE.ACCTS                                   0.313213
# PRI.CURRENT.BALANCE                                 0.146973
# PRI.SANCTIONED.AMOUNT                               0.083567
# PRI.DISBURSED.AMOUNT                                0.083373
# SEC.NO.OF.ACCTS                                     0.073349
# SEC.ACTIVE.ACCTS                                    0.073696
# SEC.OVERDUE.ACCTS                                   0.075291
# SEC.CURRENT.BALANCE                                 0.028704
# SEC.SANCTIONED.AMOUNT                               0.037574
# SEC.DISBURSED.AMOUNT                                0.037020
# PRIMARY.INSTAL.AMT                                  0.039689
# SEC.INSTAL.AMT                                      0.012456
# NEW.ACCTS.IN.LAST.SIX.MONTHS                        0.033372
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS                 0.171348
# NO.OF_INQUIRIES                                     0.024883
# loan_default                                       -0.024781
# Employment.Type.Numeric                            -0.018974
# AVERAGE.ACCT.AGE.months                             1.000000
#
# [36 rows x 36 columns]

# %%
cm = sns.light_palette("seagreen", as_cmap=True)

s = df.corr().style.background_gradient(cmap=cm)

s
# Out:
# <style  type="text/css" >
# #T_5e676_row0_col0,#T_5e676_row1_col1,#T_5e676_row2_col2,#T_5e676_row3_col3,#T_5e676_row4_col4,#T_5e676_row5_col5,#T_5e676_row6_col6,#T_5e676_row7_col7,#T_5e676_row8_col8,#T_5e676_row10_col10,#T_5e676_row11_col11,#T_5e676_row12_col12,#T_5e676_row13_col13,#T_5e676_row14_col14,#T_5e676_row15_col15,#T_5e676_row16_col16,#T_5e676_row17_col17,#T_5e676_row18_col18,#T_5e676_row19_col19,#T_5e676_row20_col20,#T_5e676_row20_col21,#T_5e676_row21_col20,#T_5e676_row21_col21,#T_5e676_row22_col22,#T_5e676_row23_col23,#T_5e676_row24_col24,#T_5e676_row25_col25,#T_5e676_row26_col26,#T_5e676_row26_col27,#T_5e676_row27_col26,#T_5e676_row27_col27,#T_5e676_row28_col28,#T_5e676_row29_col29,#T_5e676_row30_col30,#T_5e676_row31_col31,#T_5e676_row32_col32,#T_5e676_row33_col33,#T_5e676_row34_col34,#T_5e676_row35_col35{
#             background-color:  #2e8b57;
#             color:  #000000;
#         }#T_5e676_row0_col1{
#             background-color:  #529e73;
#             color:  #000000;
#         }#T_5e676_row0_col2,#T_5e676_row2_col10{
#             background-color:  #88bd9f;
#             color:  #000000;
#         }#T_5e676_row0_col3,#T_5e676_row0_col35,#T_5e676_row1_col3,#T_5e676_row3_col35,#T_5e676_row5_col32,#T_5e676_row5_col34,#T_5e676_row10_col22,#T_5e676_row13_col31,#T_5e676_row16_col24,#T_5e676_row19_col23,#T_5e676_row20_col32,#T_5e676_row21_col32,#T_5e676_row28_col32,#T_5e676_row30_col25,#T_5e676_row31_col25,#T_5e676_row32_col4,#T_5e676_row33_col8,#T_5e676_row33_col30,#T_5e676_row34_col19,#T_5e676_row35_col4{
#             background-color:  #dfece4;
#             color:  #000000;
#         }#T_5e676_row0_col4,#T_5e676_row2_col30,#T_5e676_row5_col7,#T_5e676_row5_col17,#T_5e676_row12_col4,#T_5e676_row19_col11,#T_5e676_row20_col11,#T_5e676_row21_col11,#T_5e676_row31_col11{
#             background-color:  #cce2d4;
#             color:  #000000;
#         }#T_5e676_row0_col5,#T_5e676_row0_col11,#T_5e676_row8_col4,#T_5e676_row12_col13,#T_5e676_row23_col15,#T_5e676_row26_col11,#T_5e676_row27_col11,#T_5e676_row32_col11,#T_5e676_row35_col11{
#             background-color:  #c9e0d2;
#             color:  #000000;
#         }#T_5e676_row0_col6,#T_5e676_row19_col31{
#             background-color:  #b5d5c2;
#             color:  #000000;
#         }#T_5e676_row0_col7,#T_5e676_row0_col30,#T_5e676_row1_col7,#T_5e676_row3_col15,#T_5e676_row8_col34,#T_5e676_row14_col17,#T_5e676_row19_col5,#T_5e676_row23_col16,#T_5e676_row29_col17,#T_5e676_row31_col32,#T_5e676_row32_col31,#T_5e676_row35_col30{
#             background-color:  #d4e6db;
#             color:  #000000;
#         }#T_5e676_row0_col8,#T_5e676_row2_col23,#T_5e676_row5_col22,#T_5e676_row8_col18,#T_5e676_row8_col19,#T_5e676_row8_col31,#T_5e676_row11_col24,#T_5e676_row11_col33,#T_5e676_row13_col19,#T_5e676_row16_col0,#T_5e676_row18_col4,#T_5e676_row20_col23,#T_5e676_row21_col23,#T_5e676_row25_col32,#T_5e676_row26_col32,#T_5e676_row27_col32,#T_5e676_row28_col8,#T_5e676_row29_col32,#T_5e676_row30_col0,#T_5e676_row35_col28{
#             background-color:  #e1ede5;
#             color:  #000000;
#         }#T_5e676_row0_col9,#T_5e676_row1_col9,#T_5e676_row2_col9,#T_5e676_row3_col9,#T_5e676_row4_col9,#T_5e676_row5_col9,#T_5e676_row6_col9,#T_5e676_row7_col9,#T_5e676_row8_col9,#T_5e676_row9_col0,#T_5e676_row9_col1,#T_5e676_row9_col2,#T_5e676_row9_col3,#T_5e676_row9_col4,#T_5e676_row9_col5,#T_5e676_row9_col6,#T_5e676_row9_col7,#T_5e676_row9_col8,#T_5e676_row9_col9,#T_5e676_row9_col10,#T_5e676_row9_col11,#T_5e676_row9_col12,#T_5e676_row9_col13,#T_5e676_row9_col14,#T_5e676_row9_col15,#T_5e676_row9_col16,#T_5e676_row9_col17,#T_5e676_row9_col18,#T_5e676_row9_col19,#T_5e676_row9_col20,#T_5e676_row9_col21,#T_5e676_row9_col22,#T_5e676_row9_col23,#T_5e676_row9_col24,#T_5e676_row9_col25,#T_5e676_row9_col26,#T_5e676_row9_col27,#T_5e676_row9_col28,#T_5e676_row9_col29,#T_5e676_row9_col30,#T_5e676_row9_col31,#T_5e676_row9_col32,#T_5e676_row9_col33,#T_5e676_row9_col34,#T_5e676_row9_col35,#T_5e676_row10_col9,#T_5e676_row11_col9,#T_5e676_row12_col9,#T_5e676_row13_col9,#T_5e676_row14_col9,#T_5e676_row15_col9,#T_5e676_row16_col9,#T_5e676_row17_col9,#T_5e676_row18_col9,#T_5e676_row19_col9,#T_5e676_row20_col9,#T_5e676_row21_col9,#T_5e676_row22_col9,#T_5e676_row23_col9,#T_5e676_row24_col9,#T_5e676_row25_col9,#T_5e676_row26_col9,#T_5e676_row27_col9,#T_5e676_row28_col9,#T_5e676_row29_col9,#T_5e676_row30_col9,#T_5e676_row31_col9,#T_5e676_row32_col9,#T_5e676_row33_col9,#T_5e676_row34_col9,#T_5e676_row35_col9{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_5e676_row0_col10,#T_5e676_row14_col12,#T_5e676_row20_col12,#T_5e676_row21_col12,#T_5e676_row28_col12,#T_5e676_row32_col12,#T_5e676_row35_col12{
#             background-color:  #95c3a9;
#             color:  #000000;
#         }#T_5e676_row0_col12,#T_5e676_row15_col16,#T_5e676_row20_col10,#T_5e676_row21_col10,#T_5e676_row23_col10,#T_5e676_row24_col10,#T_5e676_row26_col10,#T_5e676_row27_col10,#T_5e676_row27_col23,#T_5e676_row35_col10{
#             background-color:  #92c2a7;
#             color:  #000000;
#         }#T_5e676_row0_col13,#T_5e676_row18_col1,#T_5e676_row20_col13,#T_5e676_row21_col13,#T_5e676_row24_col1,#T_5e676_row24_col13,#T_5e676_row25_col6,#T_5e676_row25_col13,#T_5e676_row26_col13,#T_5e676_row27_col13,#T_5e676_row29_col13,#T_5e676_row30_col13,#T_5e676_row31_col35,#T_5e676_row35_col1{
#             background-color:  #c1dccc;
#             color:  #000000;
#         }#T_5e676_row0_col14,#T_5e676_row3_col30,#T_5e676_row3_col33,#T_5e676_row5_col18,#T_5e676_row5_col19,#T_5e676_row11_col34,#T_5e676_row20_col4,#T_5e676_row20_col14,#T_5e676_row21_col4,#T_5e676_row21_col14,#T_5e676_row24_col29,#T_5e676_row26_col4,#T_5e676_row27_col4,#T_5e676_row28_col4,#T_5e676_row30_col14,#T_5e676_row31_col14,#T_5e676_row32_col35,#T_5e676_row34_col15,#T_5e676_row34_col17{
#             background-color:  #dbeae1;
#             color:  #000000;
#         }#T_5e676_row0_col15,#T_5e676_row2_col7,#T_5e676_row4_col2,#T_5e676_row22_col31,#T_5e676_row31_col23,#T_5e676_row34_col2{
#             background-color:  #cfe3d7;
#             color:  #000000;
#         }#T_5e676_row0_col16,#T_5e676_row8_col17,#T_5e676_row15_col6,#T_5e676_row20_col5,#T_5e676_row21_col5,#T_5e676_row29_col24,#T_5e676_row31_col5{
#             background-color:  #d6e7dd;
#             color:  #000000;
#         }#T_5e676_row0_col17,#T_5e676_row5_col11,#T_5e676_row5_col16,#T_5e676_row14_col7,#T_5e676_row20_col7,#T_5e676_row21_col7,#T_5e676_row24_col30,#T_5e676_row26_col30,#T_5e676_row27_col30,#T_5e676_row30_col28,#T_5e676_row31_col20{
#             background-color:  #d0e4d8;
#             color:  #000000;
#         }#T_5e676_row0_col18,#T_5e676_row3_col34,#T_5e676_row7_col14,#T_5e676_row7_col23,#T_5e676_row7_col30,#T_5e676_row8_col33,#T_5e676_row10_col19,#T_5e676_row10_col31,#T_5e676_row11_col3,#T_5e676_row11_col23,#T_5e676_row13_col35,#T_5e676_row18_col24,#T_5e676_row19_col32,#T_5e676_row22_col19,#T_5e676_row23_col4,#T_5e676_row23_col14,#T_5e676_row24_col14,#T_5e676_row26_col18,#T_5e676_row27_col18,#T_5e676_row29_col14,#T_5e676_row30_col34,#T_5e676_row31_col27,#T_5e676_row32_col14,#T_5e676_row32_col19,#T_5e676_row33_col3,#T_5e676_row34_col8{
#             background-color:  #ddebe2;
#             color:  #000000;
#         }#T_5e676_row0_col19,#T_5e676_row1_col33,#T_5e676_row3_col14,#T_5e676_row3_col16,#T_5e676_row4_col14,#T_5e676_row6_col14,#T_5e676_row7_col16,#T_5e676_row7_col34,#T_5e676_row8_col14,#T_5e676_row11_col5,#T_5e676_row11_col16,#T_5e676_row12_col3,#T_5e676_row13_col18,#T_5e676_row14_col19,#T_5e676_row15_col24,#T_5e676_row23_col19,#T_5e676_row24_col19,#T_5e676_row29_col18,#T_5e676_row33_col14,#T_5e676_row33_col17,#T_5e676_row34_col18{
#             background-color:  #deece3;
#             color:  #000000;
#         }#T_5e676_row0_col20,#T_5e676_row0_col21,#T_5e676_row0_col22,#T_5e676_row0_col23,#T_5e676_row2_col20,#T_5e676_row2_col21,#T_5e676_row2_col26,#T_5e676_row2_col27,#T_5e676_row4_col19,#T_5e676_row5_col28,#T_5e676_row7_col25,#T_5e676_row7_col28,#T_5e676_row8_col0,#

# %%
df['MobileNo_Avl_Flag'].head()
# Out:
# UniqueID
# 420825    1
# 537409    1
# 417566    1
# 624493    1
# 539055    1
# Name: MobileNo_Avl_Flag, dtype: int64

# %% [markdown]
# <mark>Try to plot all columns across each other and across multiple others according to their datatype. Like there must be specific plot to use for visualizing string data (categories) vs other types</mark>
